# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2
from helperhandler import dataHolder
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load and Explore the Datasets Available

# %%
dataHolder.load_data()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))

# %%
dataHolder.dataDf
# Out:
#           Handle       Short Description
# 0      airp_data          Air Passengers
# 1      india_cpi               India CPI
# 2      beer_prod         Beer Production
# 3  anti_diabetic  AntiDiabetic Drug Sale
# 4   aus_elecprod  Electricity Production
# 5    visitor_20r  Visitors to 20 Regions
# 6   retail_sales            Retail Sales
# 7    stocks_data             Stocks Data

# %%
dataObj = dataHolder.bucket['stocks_data']
print(dataObj.long_description)
dataObj.exploratory_plot()
dataDF = dataObj.data.copy()
# Out:
# Stock Ticker Data (Custom Buisness Days), from 2010 to 2012

# %% [markdown]
# # tsEULER

# %% [markdown]
# ## Stocks Data

# %%
tsmadObj = tse.TSMAD(tsdata = dataDF, data_desc = 'Stocks Data',
                     target_columns = ['close'], categorical_columns = ['Name'],
                     dt_format = '%Y-%m-%d', dt_freq = 'B',
                     how_aggregate = {'open':'first', 'high':'max', 'low':'min', 'close':'last'},
                     force_interactive = True)

# %%
tsmadObj.get_board()

# %% [markdown]
# ## Air Passengers Data

# %%
tsmadObj = tse.TSMAD(tsdata = dataDF, data_desc = 'Air Passengers',
                     target_columns = ['Passengers'],
                     dt_format = '%Y-%m-%d', dt_freq = 'MS',
                     how_aggregate = 'mean',
                     force_interactive = True)

# %%
tsmadObj.get_board()

# %% [markdown]
# ## India CPI

# %%
tsmadObj = tse.TSMAD(tsdata = dataDF, data_desc = 'Consumer Price Index (India)',
                     target_columns = ['Urban'],
                     dt_format = '%Y-%m-%d', dt_freq = 'MS',
                     categorical_columns = ['State', 'Description'],
                     how_aggregate = 'mean',
                     force_interactive = True)

# %%
tsmadObj.get_board()

# %% [markdown]
# ## Beer Production

# %%
tsmadObj = tse.TSMAD(tsdata = dataDF, data_desc = 'Beer Production',
                     target_columns = ['MBP'],
                     dt_format = '%Y-%m-%d', dt_freq = 'MS',
                     how_aggregate = 'mean',
                     force_interactive = True)

# %%
tsmadObj.get_board()
